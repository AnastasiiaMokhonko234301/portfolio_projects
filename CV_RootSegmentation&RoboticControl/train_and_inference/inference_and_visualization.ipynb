# %%
# Import necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Load the provided root mask image
mask_path = "task5_test_image_prediction_anastasiia_234301.png"  # Update with your file path
mask_image = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

# Threshold the mask to ensure it's binary (0 for background, 255 for roots)
_, binary_mask = cv2.threshold(mask_image, 127, 255, cv2.THRESH_BINARY)

# Perform connected component analysis to segment individual roots
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(binary_mask, connectivity=8)

# Filter out small components by area (noise filtering)
min_area = 100  # Minimum area threshold to exclude noise
filtered_labels = [i for i in range(1, num_labels) if stats[i, cv2.CC_STAT_AREA] >= min_area]

# Ensure no more than 5 sections (roots)
filtered_labels = filtered_labels[:5]

# Generate individual masks for each detected root
individual_masks = []
for label in filtered_labels:
    root_mask = np.where(labels == label, 255, 0).astype(np.uint8)
    individual_masks.append(root_mask)

# Visualize individual root masks
plt.figure(figsize=(15, 5))
for i, root_mask in enumerate(individual_masks):
    plt.subplot(1, 5, i + 1)  # Ensure 1 row and max 5 sections
    plt.imshow(root_mask, cmap="viridis")
    plt.title(f"Plant {i}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# Save individual root masks
output_dir = "individual_roots"  # Directory to save masks
os.makedirs(output_dir, exist_ok=True)

for i, root_mask in enumerate(individual_masks):
    output_path = f"{output_dir}/root_{i + 1}.png"
    cv2.imwrite(output_path, root_mask)

print(f"Saved {len(individual_masks)} individual root masks in '{output_dir}' directory.")
# Out:
# Saved 5 individual root masks in 'individual_roots' directory.

# %%
# Import necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Load the provided root mask image
mask_path = "task5_test_image_prediction_anastasiia_234301.png"  # Update with your file path
mask_image = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

# Threshold the mask to ensure it's binary (0 for background, 255 for roots)
_, binary_mask = cv2.threshold(mask_image, 127, 255, cv2.THRESH_BINARY)

# Perform connected component analysis to segment individual roots
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(binary_mask, connectivity=8)

# Filter out small components by area (noise filtering)
min_area = 100  # Minimum area threshold to exclude noise
filtered_labels = [i for i in range(1, num_labels) if stats[i, cv2.CC_STAT_AREA] >= min_area]

# Ensure no more than 5 sections (roots)
filtered_labels = filtered_labels[:5]

# Generate individual masks for each detected root
individual_masks = []
for label in filtered_labels:
    root_mask = np.where(labels == label, 255, 0).astype(np.uint8)
    individual_masks.append(root_mask)

# Check if roots are detected
if len(individual_masks) > 0:
    # Visualize individual root masks
    plt.figure(figsize=(15, 5))
    for i, root_mask in enumerate(individual_masks):
        plt.subplot(1, len(individual_masks), i + 1)  # Dynamic number of sections based on roots
        plt.imshow(root_mask, cmap="viridis")
        plt.title(f"Plant {i}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()

    # Save individual root masks
    output_dir = "individual_roots"  # Directory to save masks
    os.makedirs(output_dir, exist_ok=True)

    for i, root_mask in enumerate(individual_masks):
        output_path = f"{output_dir}/root_{i + 1}.png"
        cv2.imwrite(output_path, root_mask)

    print(f"Saved {len(individual_masks)} individual root masks in '{output_dir}' directory.")
else:
    print("No valid roots detected!")
# Out:
# Saved 5 individual root masks in 'individual_roots' directory.

# %%
# Import necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Load the provided root mask image
mask_path = "task5_test_image_prediction_anastasiia_234301.png"  # Update with your file path
mask_image = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

# Threshold the mask to ensure it's binary (0 for background, 255 for roots)
_, binary_mask = cv2.threshold(mask_image, 127, 255, cv2.THRESH_BINARY)

# Perform connected component analysis to segment individual roots
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(binary_mask, connectivity=8)

# Filter out small components by area (noise filtering)
min_area = 500  # Increase the minimum area to exclude small particles or noise
filtered_labels = [i for i in range(1, num_labels) if stats[i, cv2.CC_STAT_AREA] >= min_area]

# Ensure no more than 5 sections (roots)
filtered_labels = filtered_labels[:5]

# Generate individual masks for each detected root
individual_masks = []
for label in filtered_labels:
    root_mask = np.where(labels == label, 255, 0).astype(np.uint8)
    individual_masks.append(root_mask)

# Visualize individual root masks only if roots are detected
plt.figure(figsize=(15, 5))
for i, root_mask in enumerate(individual_masks):
    plt.subplot(1, 5, i + 1)  # Ensure 1 row and max 5 sections
    plt.imshow(root_mask, cmap="viridis")
    plt.title(f"Root {i + 1}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# Save individual root masks
output_dir = "individual_roots"  # Directory to save masks
os.makedirs(output_dir, exist_ok=True)

for i, root_mask in enumerate(individual_masks):
    output_path = f"{output_dir}/root_{i + 1}.png"
    cv2.imwrite(output_path, root_mask)

print(f"Saved {len(individual_masks)} individual root masks in '{output_dir}' directory.")
# Out:
# Saved 5 individual root masks in 'individual_roots' directory.

# %%
# Import necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Load the provided root mask image
mask_path = "task5_test_image_prediction_anastasiia_234301.png"  # Update with your file path
mask_image = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

# Threshold the mask to ensure it's binary (0 for background, 255 for roots)
_, binary_mask = cv2.threshold(mask_image, 127, 255, cv2.THRESH_BINARY)

# Perform connected component analysis to segment individual roots
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(binary_mask, connectivity=8)

# Filter out small components by area (noise filtering)
min_area = 500  # Minimum area threshold to exclude small particles or noise
filtered_labels = [i for i in range(1, num_labels) if stats[i, cv2.CC_STAT_AREA] >= min_area]

# Ensure no more than 5 sections (roots)
filtered_labels = filtered_labels[:5]

# Generate individual masks for each detected root and crop them to bounding boxes
individual_masks = []
cropped_images = []
for label in filtered_labels:
    root_mask = np.where(labels == label, 255, 0).astype(np.uint8)
    individual_masks.append(root_mask)

    # Get bounding box of the root
    x, y, w, h = stats[label, cv2.CC_STAT_LEFT], stats[label, cv2.CC_STAT_TOP], stats[label, cv2.CC_STAT_WIDTH], stats[label, cv2.CC_STAT_HEIGHT]
    
    # Crop the root mask to its bounding box
    cropped_root = root_mask[y:y+h, x:x+w]
    cropped_images.append(cropped_root)

# Visualize cropped individual root masks (zoomed-in views)
plt.figure(figsize=(15, 5))
for i, cropped_root in enumerate(cropped_images):
    plt.subplot(1, 5, i + 1)  # Ensure 1 row and max 5 sections
    plt.imshow(cropped_root, cmap="viridis")
    plt.title(f"Root {i + 1}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# Save cropped root masks
output_dir = "zoomed_roots"  # Directory to save zoomed masks
os.makedirs(output_dir, exist_ok=True)

for i, cropped_root in enumerate(cropped_images):
    output_path = f"{output_dir}/zoomed_root_{i + 1}.png"
    cv2.imwrite(output_path, cropped_root)

print(f"Saved {len(cropped_images)} zoomed-in root masks in '{output_dir}' directory.")
# Out:
# Saved 5 zoomed-in root masks in 'zoomed_roots' directory.

# %%
# Import necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Load the mask image
mask_path = "task5_test_image_prediction_anastasiia_234301.png"  # Update with your file path
mask_image = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

# Threshold the mask to ensure it's binary (0 for background, 255 for roots)
_, binary_mask = cv2.threshold(mask_image, 127, 255, cv2.THRESH_BINARY)

# Perform connected component analysis to segment individual roots
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(binary_mask, connectivity=8)

# Filter out small components by area (noise filtering)
min_area = 500  # Minimum area threshold to exclude small particles or noise
filtered_labels = [i for i in range(1, num_labels) if stats[i, cv2.CC_STAT_AREA] >= min_area]

# Ensure no more than 5 sections (roots)
filtered_labels = filtered_labels[:5]

# Generate cropped masks for each detected root
cropped_roots = []
for label in filtered_labels:
    # Get bounding box of the root
    x, y, w, h = stats[label, cv2.CC_STAT_LEFT], stats[label, cv2.CC_STAT_TOP], stats[label, cv2.CC_STAT_WIDTH], stats[label, cv2.CC_STAT_HEIGHT]
    
    # Crop the root region from the mask
    cropped_root = binary_mask[y:y+h, x:x+w]
    cropped_roots.append(cropped_root)

# Visualize cropped masks (zoomed-in roots)
plt.figure(figsize=(15, 5))
for i, cropped_root in enumerate(cropped_roots):
    plt.subplot(1, 5, i + 1)  # Ensure 1 row and max 5 sections
    plt.imshow(cropped_root, cmap="gray")
    plt.title(f"Root {i + 1}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# Save cropped root masks
output_dir = "cropped_roots_masks"  # Directory to save cropped masks
os.makedirs(output_dir, exist_ok=True)

for i, cropped_root in enumerate(cropped_roots):
    output_path = f"{output_dir}/cropped_root_{i + 1}.png"
    cv2.imwrite(output_path, cropped_root)

print(f"Saved {len(cropped_roots)} cropped root masks in '{output_dir}' directory.")
# Out:
# Saved 5 cropped root masks in 'cropped_roots_masks' directory.

# %%
# Import necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Load the mask image
mask_path = "task5_test_image_prediction_anastasiia_234301.png"  # Update with your file path
mask_image = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

# Threshold the mask to ensure it's binary (0 for background, 255 for roots)
_, binary_mask = cv2.threshold(mask_image, 127, 255, cv2.THRESH_BINARY)

# Perform connected component analysis to segment individual roots
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(binary_mask, connectivity=8)

# Filter out small components by area (noise filtering)
min_area = 500  # Minimum area threshold to exclude small particles or noise
filtered_labels = [i for i in range(1, num_labels) if stats[i, cv2.CC_STAT_AREA] >= min_area]

# Ensure no more than 4 sections (roots)
filtered_labels = filtered_labels[:4]

# Generate cropped masks for each detected root
cropped_roots = []
for label in filtered_labels:
    # Get bounding box of the root
    x, y, w, h = stats[label, cv2.CC_STAT_LEFT], stats[label, cv2.CC_STAT_TOP], stats[label, cv2.CC_STAT_WIDTH], stats[label, cv2.CC_STAT_HEIGHT]
    
    # Crop the root region from the mask
    cropped_root = binary_mask[y:y+h, x:x+w]
    cropped_roots.append(cropped_root)

# Visualize cropped masks (zoomed-in roots)
plt.figure(figsize=(15, 5))
for i, cropped_root in enumerate(cropped_roots):
    plt.subplot(1, 4, i + 1)  # Ensure 1 row and max 4 sections
    plt.imshow(cropped_root, cmap="gray")
    plt.title(f"Root {i + 1}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# Save cropped root masks
output_dir = "cropped_roots_masks"  # Directory to save cropped masks
os.makedirs(output_dir, exist_ok=True)

for i, cropped_root in enumerate(cropped_roots):
    output_path = f"{output_dir}/cropped_root_{i + 1}.png"
    cv2.imwrite(output_path, cropped_root)

print(f"Saved {len(cropped_roots)} cropped root masks in '{output_dir}' directory.")
# Out:
# Saved 4 cropped root masks in 'cropped_roots_masks' directory.

# %%
# Task 6
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Load the predicted mask from Task 5
predicted_mask_path = "task5_test_image_prediction_anastasiia_234301.png"  # Update your mask file path
binary_mask = cv2.imread(predicted_mask_path, cv2.IMREAD_GRAYSCALE)

# Ensure binary mask (0 or 255)
binary_mask[binary_mask > 0] = 255

plt.imshow(binary_mask, cmap="gray")
plt.title("Step 1: Binary Mask")
plt.axis("off")
plt.show()

# Step 2: Apply morphological operations to clean the mask
kernel = np.ones((4, 4), np.uint8)
cleaned_mask = cv2.morphologyEx(binary_mask, cv2.MORPH_CLOSE, kernel, iterations=2)  # Close small gaps
cleaned_mask = cv2.morphologyEx(cleaned_mask, cv2.MORPH_OPEN, kernel, iterations=1)  # Remove small noise

plt.figure()
plt.title("Step 2: Morphological Operations")
plt.imshow(cleaned_mask, cmap="gray")
plt.axis("off")
plt.show()

# Step 3: Apply additional thresholding to enhance roots
_, thresholded_mask = cv2.threshold(cleaned_mask, 127, 255, cv2.THRESH_BINARY)

plt.figure()
plt.title("Step 3: Thresholded Mask")
plt.imshow(thresholded_mask, cmap="gray")
plt.axis("off")
plt.show()

# Step 4: Find connected components and filter
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresholded_mask)

# Step 5: Filter objects based on area, aspect ratio, and position
min_root_area = 1500  # Minimum area to consider an object as a root
aspect_ratio_threshold = 1.7  # Minimum aspect ratio (length/width) for roots
y_threshold = 100  # Exclude components too close to the top

filtered_mask = np.zeros_like(binary_mask, dtype=np.uint8)

for label_idx in range(1, num_labels):  # Skip background (label 0)
    x, y, w, h, area = stats[label_idx, cv2.CC_STAT_LEFT], stats[label_idx, cv2.CC_STAT_TOP], \
                       stats[label_idx, cv2.CC_STAT_WIDTH], stats[label_idx, cv2.CC_STAT_HEIGHT], \
                       stats[label_idx, cv2.CC_STAT_AREA]

    # Calculate aspect ratio (length/width)
    aspect_ratio = max(w, h) / min(w, h) if min(w, h) > 0 else 0

    # Filter based on area, aspect ratio, and position
    if area >= min_root_area and aspect_ratio >= aspect_ratio_threshold:
        if y > y_threshold:  # Exclude components near the top
            filtered_mask[labels == label_idx] = 255

# Apply small morphological operations to remove tiny noise
final_kernel = np.ones((3, 3), np.uint8)
filtered_mask = cv2.morphologyEx(filtered_mask, cv2.MORPH_OPEN, final_kernel, iterations=1)

plt.figure()
plt.title("Step 5: Filtered Mask with Position Filtering")
plt.imshow(filtered_mask, cmap="gray")
plt.axis("off")
plt.show()

# Step 6: Extract individual roots
num_labels_filtered, labels_filtered, stats_filtered, _ = cv2.connectedComponentsWithStats(filtered_mask)

individual_roots = []
for label_idx in range(1, num_labels_filtered):  # Skip background
    root_mask = np.zeros_like(filtered_mask, dtype=np.uint8)
    root_mask[labels_filtered == label_idx] = 255
    individual_roots.append(root_mask)

# Limit to 4 roots (if more detected)
individual_roots = individual_roots[:4]

# Step 7: Visualize individual roots
fig, axes = plt.subplots(1, len(individual_roots), figsize=(15, 5))
for i, root_mask in enumerate(individual_roots):
    axes[i].imshow(root_mask, cmap="inferno")
    axes[i].axis("off")
    axes[i].set_title(f"Root {i+1}")
plt.tight_layout()
plt.show()

# Save individual roots
output_dir = "individual_roots_task6"
os.makedirs(output_dir, exist_ok=True)
for i, root_mask in enumerate(individual_roots):
    output_path = os.path.join(output_dir, f"root_{i+1}.png")
    cv2.imwrite(output_path, root_mask)

print(f"Saved {len(individual_roots)} individual root masks in '{output_dir}' directory.")
# Out:
# Saved 4 individual root masks in 'individual_roots_task6' directory.

# %%
# Task 6: Root Segmentation and Visualization
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Step 1: Load the predicted mask from Task 5
# The predicted mask contains binary data where root pixels are white (255), and the background is black (0)
predicted_mask_path = "task5_test_image_prediction_anastasiia_234301.png"  # Update file path as needed
binary_mask = cv2.imread(predicted_mask_path, cv2.IMREAD_GRAYSCALE)

# Ensure binary mask (convert any non-zero values to 255)
binary_mask[binary_mask > 0] = 255

# Step 2: Clean the mask using morphological operations
# Morphological operations are applied to close small gaps in the roots and remove small noise
kernel = np.ones((4, 4), np.uint8)  # Define kernel for morphological operations
cleaned_mask = cv2.morphologyEx(binary_mask, cv2.MORPH_CLOSE, kernel, iterations=2)  # Close small gaps
cleaned_mask = cv2.morphologyEx(cleaned_mask, cv2.MORPH_OPEN, kernel, iterations=1)  # Remove small noise

# Step 3: Identify connected components (roots) in the cleaned mask
# Connected component analysis labels all connected regions in the binary mask
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(cleaned_mask)

# Step 4: Filter connected components based on size and shape
# Only retain valid roots based on area and aspect ratio constraints
min_root_area = 1500  # Minimum area to consider a region as a root
aspect_ratio_threshold = 1.7  # Minimum aspect ratio (length/width) for root structures
y_threshold = 100  # Exclude components too close to the top boundary

filtered_roots = []  # List to store masks for valid roots
for label_idx in range(1, num_labels):  # Skip background (label 0)
    # Extract properties of the component
    x, y, w, h, area = stats[label_idx, cv2.CC_STAT_LEFT], stats[label_idx, cv2.CC_STAT_TOP], \
                       stats[label_idx, cv2.CC_STAT_WIDTH], stats[label_idx, cv2.CC_STAT_HEIGHT], \
                       stats[label_idx, cv2.CC_STAT_AREA]
    
    # Calculate the aspect ratio (length/width)
    aspect_ratio = max(w, h) / min(w, h) if min(w, h) > 0 else 0
    
    # Apply filtering criteria: area, aspect ratio, and position
    if area >= min_root_area and aspect_ratio >= aspect_ratio_threshold and y > y_threshold:
        # Create a mask for the valid root
        root_mask = np.zeros_like(binary_mask, dtype=np.uint8)
        root_mask[labels == label_idx] = 255
        filtered_roots.append(root_mask)

# Step 5: Limit the number of detected roots to 4 (since there are only 4 plants)
filtered_roots = filtered_roots[:4]

# Step 6: Visualize individual roots
# Display each root in its own subplot, zoomed in to the bounding box of the root
fig, axes = plt.subplots(1, len(filtered_roots), figsize=(15, 5))  # Create a row of subplots
for i, root_mask in enumerate(filtered_roots):
    # Calculate the bounding box for the root to crop the visualization
    y_indices, x_indices = np.where(root_mask > 0)
    if len(y_indices) > 0 and len(x_indices) > 0:  # Ensure the root is not empty
        y_min, y_max = y_indices.min(), y_indices.max()
        x_min, x_max = x_indices.min(), x_indices.max()
        
        # Crop the root mask to its bounding box
        cropped_root = root_mask[y_min:y_max+1, x_min:x_max+1]
        
        # Plot the cropped root in the subplot
        axes[i].imshow(cropped_root, cmap="inferno")
        axes[i].axis("off")  # Hide axes for a cleaner visualization
        axes[i].set_title(f"Plant {i}")  # Label each root by its index
    else:
        axes[i].axis("off")  # If no valid root, hide the subplot

plt.tight_layout()
plt.show()

# %%
# Task 6: Root Segmentation and Visualization
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Step 1: Load the predicted mask from Task 5
# The predicted mask contains binary data where root pixels are white (255), and the background is black (0)
predicted_mask_path = "task5_test_image_prediction_anastasiia_234301.png"  # Update file path as needed
binary_mask = cv2.imread(predicted_mask_path, cv2.IMREAD_GRAYSCALE)

# Ensure binary mask (convert any non-zero values to 255)
binary_mask[binary_mask > 0] = 255

# Step 2: Clean the mask using morphological operations
# Morphological operations are applied to close small gaps in the roots and remove small noise
kernel = np.ones((4, 4), np.uint8)  # Define kernel for morphological operations
cleaned_mask = cv2.morphologyEx(binary_mask, cv2.MORPH_CLOSE, kernel, iterations=2)  # Close small gaps
cleaned_mask = cv2.morphologyEx(cleaned_mask, cv2.MORPH_OPEN, kernel, iterations=1)  # Remove small noise

# Step 3: Identify connected components (roots) in the cleaned mask
# Connected component analysis labels all connected regions in the binary mask
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(cleaned_mask)

# Step 4: Filter connected components based on size and shape
# Only retain valid roots based on area and aspect ratio constraints
min_root_area = 1500  # Minimum area to consider a region as a root
aspect_ratio_threshold = 1.7  # Minimum aspect ratio (length/width) for root structures
y_threshold = 100  # Exclude components too close to the top boundary

filtered_roots = []  # List to store masks for valid roots
for label_idx in range(1, num_labels):  # Skip background (label 0)
    # Extract properties of the component
    x, y, w, h, area = stats[label_idx, cv2.CC_STAT_LEFT], stats[label_idx, cv2.CC_STAT_TOP], \
                       stats[label_idx, cv2.CC_STAT_WIDTH], stats[label_idx, cv2.CC_STAT_HEIGHT], \
                       stats[label_idx, cv2.CC_STAT_AREA]
    
    # Calculate the aspect ratio (length/width)
    aspect_ratio = max(w, h) / min(w, h) if min(w, h) > 0 else 0
    
    # Apply filtering criteria: area, aspect ratio, and position
    if area >= min_root_area and aspect_ratio >= aspect_ratio_threshold and y > y_threshold:
        # Create a mask for the valid root
        root_mask = np.zeros_like(binary_mask, dtype=np.uint8)
        root_mask[labels == label_idx] = 255
        filtered_roots.append(root_mask)

# Step 5: Limit the number of detected roots to 4 (since there are only 4 plants)
filtered_roots = filtered_roots[:4]

# Step 6: Visualize individual roots
# Display each root in its own subplot, zoomed in to the bounding box of the root
fig, axes = plt.subplots(1, len(filtered_roots), figsize=(15, 5))  # Create a row of subplots
for i, root_mask in enumerate(filtered_roots):
    # Calculate the bounding box for the root to crop the visualization
    y_indices, x_indices = np.where(root_mask > 0)
    if len(y_indices) > 0 and len(x_indices) > 0:  # Ensure the root is not empty
        y_min, y_max = y_indices.min(), y_indices.max()
        x_min, x_max = x_indices.min(), x_indices.max()
        
        # Crop the root mask to its bounding box
        cropped_root = root_mask[y_min:y_max+1, x_min:x_max+1]
        
        # Plot the cropped root in the subplot
        axes[i].imshow(cropped_root, cmap="plasma")  # Use plasma colormap for consistency
        axes[i].axis("off")  # Hide axes for a cleaner visualization
        axes[i].set_title(f"Plant {i}")  # Label each root by its index
    else:
        axes[i].axis("off")  # If no valid root, hide the subplot

plt.tight_layout()
plt.show()

# %%
# Task 6: Root Segmentation and Visualization with Purple Background and Yellow Roots
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# Step 1: Load the predicted mask from Task 5
predicted_mask_path = "task5_test_image_prediction_anastasiia_234301.png"  # Update file path as needed
binary_mask = cv2.imread(predicted_mask_path, cv2.IMREAD_GRAYSCALE)

# Ensure binary mask (convert any non-zero values to 255)
binary_mask[binary_mask > 0] = 255

# Step 2: Clean the mask using morphological operations
kernel = np.ones((4, 4), np.uint8)  # Define kernel for morphological operations
cleaned_mask = cv2.morphologyEx(binary_mask, cv2.MORPH_CLOSE, kernel, iterations=2)  # Close small gaps
cleaned_mask = cv2.morphologyEx(cleaned_mask, cv2.MORPH_OPEN, kernel, iterations=1)  # Remove small noise

# Step 3: Identify connected components (roots) in the cleaned mask
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(cleaned_mask)

# Step 4: Filter connected components based on size and shape
min_root_area = 1500  # Minimum area to consider a region as a root
aspect_ratio_threshold = 1.7  # Minimum aspect ratio (length/width) for root structures
y_threshold = 100  # Exclude components too close to the top boundary

filtered_roots = []  # List to store masks for valid roots
for label_idx in range(1, num_labels):  # Skip background (label 0)
    x, y, w, h, area = stats[label_idx, cv2.CC_STAT_LEFT], stats[label_idx, cv2.CC_STAT_TOP], \
                       stats[label_idx, cv2.CC_STAT_WIDTH], stats[label_idx, cv2.CC_STAT_HEIGHT], \
                       stats[label_idx, cv2.CC_STAT_AREA]
    
    aspect_ratio = max(w, h) / min(w, h) if min(w, h) > 0 else 0  # Calculate aspect ratio
    
    if area >= min_root_area and aspect_ratio >= aspect_ratio_threshold and y > y_threshold:
        root_mask = np.zeros_like(binary_mask, dtype=np.uint8)
        root_mask[labels == label_idx] = 255
        filtered_roots.append(root_mask)

# Limit to 4 roots (since there are only 4 plants)
filtered_roots = filtered_roots[:4]

# Step 5: Visualize individual roots
fig, axes = plt.subplots(1, len(filtered_roots), figsize=(15, 5))  # Create a row of subplots
for i, root_mask in enumerate(filtered_roots):
    # Calculate the bounding box for the root to crop the visualization
    y_indices, x_indices = np.where(root_mask > 0)
    if len(y_indices) > 0 and len(x_indices) > 0:  # Ensure the root is not empty
        y_min, y_max = y_indices.min(), y_indices.max()
        x_min, x_max = x_indices.min(), x_indices.max()
        
        # Crop the root mask to its bounding box
        cropped_root = root_mask[y_min:y_max+1, x_min:x_max+1]
        
        # Convert the cropped root to a colored image
        colored_image = np.zeros((*cropped_root.shape, 3), dtype=np.uint8)  # Initialize RGB image
        colored_image[..., 0] = 128  # Set blue channel for purple background
        colored_image[..., 1] = 0    # Set green channel for purple background
        colored_image[..., 2] = 128  # Set red channel for purple background
        
        # Overlay yellow roots (set root pixels to yellow)
        root_indices = np.where(cropped_root > 0)
        colored_image[root_indices[0], root_indices[1], :] = [255, 255, 0]  # Yellow color for roots
        
        # Plot the colored root in the subplot
        axes[i].imshow(colored_image)
        axes[i].axis("off")  # Hide axes for a cleaner visualization
        axes[i].set_title(f"Plant {i}")  # Label each root by its index
    else:
        axes[i].axis("off")  # If no valid root, hide the subplot

plt.tight_layout()
plt.show()
