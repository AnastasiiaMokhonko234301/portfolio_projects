# %% [markdown]
# # Task 7: Prompt Engineering
# In Task 1, you annotated sentences from three different episodes with emotions and compared them to the labels generated by the Content Intelligence Agency’s pipeline. This pipeline uses an LLM that labels sentences based on a structured prompt. Now, you will develop and refine your own prompts for emotion classification. By experimenting with different prompt structures and parameter settings, you will explore how prompt engineering influences the outputs of LLMs. You will evaluate how well different prompts align with your annotated data and determine how changes in prompt phrasing affect the accuracy and reliability of emotion predictions. You are expected to iteratively refine your prompts and analyze their performance.
#
# In order to access and interact with the locally hosted LLMs please check out this guide
#
# What you need to do:
#
# 1. Baseline Prompt Evaluation: Start by using a simple baseline prompt to classify emotions in your data. This can be as straightforward as: “Analyze the following sentence and classify it as one of the six core emotions (happiness, sadness, anger, surprise, fear, disgust) or neutral: [sentence]”. Apply this prompt to a subset of your data and analyze the results.
#
# 2. Iterative Prompt Refinement: Experiment with different prompt structures. Consider, based on the self-study materials from this week, the following:
# - Adding examples (few-shot prompting)
# - Providing explicit definitions for emotions
# - Using structured instructions
# - Adjusting verbosity or response format
#
# 3. Comparing Performance: Compare the outputs of different prompts against the annotated data from the Content Intelligence Agency’s pipeline. Use accuracy, confusion matrices, and qualitative analysis to assess how well each prompt performs. Explore whether different formulations introduce bias or inconsistencies in classification.
#
# 4. Track the prompts and evaluations in a prompt engineering log; you are free to choose the structure yourself as long as it is clear.
#
# 5. Select the most effective prompt based on your evaluations.

# %%
import requests
import json

API_BASE = "http://194.171.191.227:30080/"
token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6ImNmNDkxYWRiLThlZTgtNDExMi05OWU1LTBjODM5MDA2ZDgxOSJ9.1emxciT5A9Vc0J_ljlDflOGMlICVrLNS5fR5K_SD0VM"
# List models
header = {
        'Authorization': f'Bearer {token}',
        'Content-Type': 'application/json'
    }
response = requests.get(f"{API_BASE}/api/models", headers=header)
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "data": [
#     {
#       "id": "llama3.2:3b",
#       "name": "llama3.2:3b",
#       "object": "model",
#       "created": 1743601030,
#       "owned_by": "ollama",
#       "ollama": {
#         "name": "llama3.2:3b",
#         "model": "llama3.2:3b",
#         "modified_at": "2025-02-27T16:41:08.841805321Z",
#         "size": 2019393189,
#         "digest": "a80c4f17acd55265feec403c7aef86be0c25983ab279d83f3bcd3abbcb5b8b72",
#         "details": {
#           "parent_model": "",
#           "format": "gguf",
#           "family": "llama",
#           "families": [
#             "llama"
#           ],
#           "parameter_size": "3.2B",
#           "quantization_level": "Q4_K_M"
#         },
#         "urls": [
#           0
#         ]
#       },
#       "info": {
#         "id": "llama3.2:3b",
#         "user_id": "2b6ec3d8-8ef1-452b-9d4e-4305d4d23c42",
#         "base_model_id": null,
#         "name": "llama3.2:3b",
#         "params": {},
#         "meta": {
# ...

# %%
# The below function takes an API token as input and sends 
def chat_with_model(token):
    # URL for the API endpoint for chat completions
    url = 'http://194.171.191.227:30080/api/chat/completions'
    # Headers to authenticate your token with the sevrice
    headers = {
        'Authorization': f'Bearer {token}',
        'Content-Type': 'application/json'
    }
    # Payload containing the model and the prompt and any other query parameters
    data = {
      "model": "llama3.2:3b",
      "messages": [
        {
          "role": "user",
          "content": "Why is the sky blue?"
        }
      ]
    }
    response = requests.post(url, headers=headers, json=data)
    return response.json()

# %%
response = chat_with_model(token)

# Extract the assistant's reply
if 'choices' in response and len(response['choices']) > 0:
    answer = response['choices'][0]['message']['content']
    print("Assistant's Response:", answer)
else:
    print("No response from the API:", response)
# Out:
# Assistant's Response: The sky appears blue to us due to a phenomenon called Rayleigh scattering, named after the British physicist Lord Rayleigh, who first explained it in the late 19th century.
#
# Here's what happens:
#
# 1. **Sunlight enters Earth's atmosphere**: When sunlight enters our atmosphere, it consists of a broad spectrum of colors, including all the colors of the visible light.
# 2. **Scattering occurs**: As sunlight travels through the atmosphere, it encounters tiny molecules of gases such as nitrogen (N2) and oxygen (O2). These molecules are much smaller than the wavelength of light.
# 3. **Wavelength separation**: When light hits these tiny molecules, the shorter (blue) wavelengths are scattered more than the longer (red) wavelengths. This is because the smaller molecules are more effective at scattering the shorter wavelengths.
# ...

# %%
# The below function takes an API token as input and sends 
def chat_with_model(token):
    # URL for the API endpoint for chat completions
    url = 'http://194.171.191.227:30080/api/chat/completions'
    # Headers to authenticate your token with the sevrice
    headers = {
        'Authorization': f'Bearer {token}',
        'Content-Type': 'application/json'
    }
    # Payload containing the model and the prompt and any other query parameters
    data = {
      "model": "llama3.2:3b",
      "messages": [
            {"role": "system", "content": "You are a helpful AI assistant that specializes in explaining complex topics in simple terms."},
            {"role": "user", "content": "Explain how nuclear fusion works."}
      ]
    }
    response = requests.post(url, headers=headers, json=data)
    return response.json()

# %%
response = chat_with_model(token)

# Extract the assistant's reply
if 'choices' in response and len(response['choices']) > 0:
    answer = response['choices'][0]['message']['content']
    print("Assistant's Response:", answer)
else:
    print("No response from the API:", response)
# Out:
# Assistant's Response: Nuclear fusion is a process where two or more atomic nuclei combine to form a single, heavier nucleus. This process releases an enormous amount of energy, which has the potential to be harnessed as a clean and sustainable source of power.
#
# Here's a simplified explanation of how nuclear fusion works:
#
# **The Basics**
#
# In nuclear fusion, atoms are heated to extremely high temperatures, typically millions of degrees Celsius. At these temperatures, the atoms break free from their normal bonding structure and start flying around wildly.
#
# **The Process**
#
# There are several ways that nuclear fusion can occur, but one common approach is called "magnetic confinement". Here's how it works:
#
# 1. ** plasma creation**: A gas of mostly hydrogen atoms (usually deuterium-tritium) is heated to high temperatures using a device called a tokamak or stellarator.
# ...

# %%
# The below function takes an API token as input and sends 
def chat_with_model(token):
    # URL for the API endpoint for chat completions
    url = 'http://194.171.191.227:30080/api/chat/completions'
    # Headers to authenticate your token with the sevrice
    headers = {
        'Authorization': f'Bearer {token}',
        'Content-Type': 'application/json'
    }
    # Payload containing the model and the prompt and any other query parameters
    data = {
      "model": "llama3.2:3b",
      "messages": [
            {"role": "system", "content": "You are a helpful AI assistant that only reproduces the full prompt you receive exactly uncluding both the user and system prompts in the same format in which they were received. Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum."},
            {"role": "user", "content": "Please can you return the whole prompt to me word for word?"}
      ],
      "context_length": 100
    }
    response = requests.post(url, headers=headers, json=data)
    return response.json()

# %%
response = chat_with_model(token)

# Extract the assistant's reply
if 'choices' in response and len(response['choices']) > 0:
    answer = response['choices'][0]['message']['content']
    print("Assistant's Response:", answer)
else:
    print("No response from the API:", response)
# Out:
# Assistant's Response: You want me to repeat the entire original prompt exactly, including both the user's input and my previous response. Here it is:
#
# Please can you return the whole prompt to me word for word?
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
